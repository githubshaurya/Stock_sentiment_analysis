# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time

# %%
API_KEY = 'HTmoDru9h7CiP13MiwrdpdC2gItAWs7e'

# %%
BASE_URL = 'https://api.nytimes.com/svc/archive/v1'

# %%
def fetch_articles(year, month, api_key):
    url = f"{BASE_URL}/{year}/{month}.json"
    params = {'api-key': api_key}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json()
    elif response.status_code == 401:
        raise Exception("Invalid API key. Please check your API key and try again.")
    else:
        print(f"API request failed with status code {response.status_code} for {year}-{month}")
        return None

# %%
def extract_finance_headlines(articles):
    finance_keywords = ['Tesla', 'business', 'economy', 'market', 'stock', 'investment']
    #used keywords for apple: apple, stock, market and iphne
    #used keywords for Nvidia: Nvidia, GPU, stock, market, processor
    headlines = []
    for article in articles:
        news_desk = article.get('news_desk', '').lower()
        section_name = article.get('section_name', '').lower()
        keywords = [keyword['value'].lower() for keyword in article.get('keywords', [])]
        if any(kw in news_desk for kw in finance_keywords) or any(kw in section_name for kw in finance_keywords) or any(kw in keywords for kw in finance_keywords):
            headlines.append(article['headline']['main'])
        if len(headlines) == 27:  # Collect up to 27 headlines
            break
    return headlines

# %%
def collect_headlines(start_date, end_date, api_key):
    headlines_data = []

    current_date = start_date
    while current_date <= end_date:
        year = current_date.year
        month = current_date.month
        articles_data = fetch_articles(year, month, api_key)
        if articles_data:
            articles = articles_data['response']['docs']
            date_str = current_date.strftime('%Y-%m-%d')
            daily_articles = [article for article in articles if article['pub_date'].startswith(date_str)]
            headlines = extract_finance_headlines(daily_articles)
            headlines_data.append({'published_date': date_str, 'headlines': headlines})
            print(f"Collected {len(headlines)} headlines for {date_str}")
        current_date += timedelta(days=1)
        time.sleep(12)  # To respect rate limits

    return pd.DataFrame(headlines_data)

# %%
start_date = datetime(2023, 1, 1)
end_date = datetime(2024, 4, 10)
try:
    df_headlines = collect_headlines(start_date, end_date, API_KEY)
    df_headlines.to_csv('finance_headlines_nw.csv', index=False)
    print("Headlines successfully collected and saved to finance_headlines.csv")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Collected 4 headlines for 2023-01-01
# Collected 4 headlines for 2023-01-02
# Collected 12 headlines for 2023-01-03
# Collected 13 headlines for 2023-01-04
# Collected 11 headlines for 2023-01-05
# Collected 13 headlines for 2023-01-06
# Collected 8 headlines for 2023-01-07
# Collected 5 headlines for 2023-01-08
# Collected 6 headlines for 2023-01-09
# Collected 15 headlines for 2023-01-10
# Collected 12 headlines for 2023-01-11
# Collected 17 headlines for 2023-01-12
# Collected 16 headlines for 2023-01-13
# Collected 6 headlines for 2023-01-14
# Collected 3 headlines for 2023-01-15
# Collected 5 headlines for 2023-01-16
# Collected 16 headlines for 2023-01-17
# Collected 12 headlines for 2023-01-18
# Collected 12 headlines for 2023-01-19
# Collected 17 headlines for 2023-01-20
# Collected 6 headlines for 2023-01-21
# Collected 5 headlines for 2023-01-22
# Collected 10 headlines for 2023-01-23
# Collected 14 headlines for 2023-01-24
# Collected 11 headlines for 2023-01-25
# Collected 18 headlines for 2023-01-26
# Collected 14 headlines for 2023-01-27
# Collected 9 headlines for 2023-01-28
# Collected 2 headlines for 2023-01-29
# Collected 15 headlines for 2023-01-30
# Collected 16 headlines for 2023-01-31
# Collected 20 headlines for 2023-02-01
# Collected 17 headlines for 2023-02-02
# Collected 14 headlines for 2023-02-03
# Collected 7 headlines for 2023-02-04
# Collected 4 headlines for 2023-02-05
# Collected 12 headlines for 2023-02-06
# Collected 14 headlines for 2023-02-07
# Collected 10 headlines for 2023-02-08
# Collected 20 headlines for 2023-02-09
# Collected 15 headlines for 2023-02-10
# Collected 6 headlines for 2023-02-11
# Collected 4 headlines for 2023-02-12
# Collected 12 headlines for 2023-02-13
# Collected 17 headlines for 2023-02-14
# Collected 13 headlines for 2023-02-15
# Collected 22 headlines for 2023-02-16
# Collected 14 headlines for 2023-02-17
# Collected 6 headlines for 2023-02-18
# Collected 3 headlines for 2023-02-19
# Collected 3 headlines for 2023-02-20
# Collected 15 headlines for 2023-02-21
# Collected 11 headlines for 2023-02-22
# Collected 15 headlines for 2023-02-23
# Collected 13 headlines for 2023-02-24
# Collected 10 headlines for 2023-02-25
# Collected 5 headlines for 2023-02-26
# Collected 10 headlines for 2023-02-27
# Collected 13 headlines for 2023-02-28
# Collected 12 headlines for 2023-03-01
# Collected 7 headlines for 2023-03-02
# Collected 11 headlines for 2023-03-03
# Collected 6 headlines for 2023-03-04
# Collected 6 headlines for 2023-03-05
# Collected 6 headlines for 2023-03-06
# Collected 15 headlines for 2023-03-07
# Collected 14 headlines for 2023-03-08
# Collected 12 headlines for 2023-03-09
# Collected 17 headlines for 2023-03-10
# Collected 5 headlines for 2023-03-11
# Collected 6 headlines for 2023-03-12
# Collected 26 headlines for 2023-03-13
# Collected 20 headlines for 2023-03-14
# Collected 15 headlines for 2023-03-15
# Collected 20 headlines for 2023-03-16
# Collected 16 headlines for 2023-03-17
# Collected 7 headlines for 2023-03-18
# Collected 5 headlines for 2023-03-19
# Collected 11 headlines for 2023-03-20
# Collected 15 headlines for 2023-03-21
# Collected 18 headlines for 2023-03-22
# Collected 20 headlines for 2023-03-23
# Collected 11 headlines for 2023-03-24
# Collected 6 headlines for 2023-03-25
# Collected 5 headlines for 2023-03-26
# Collected 17 headlines for 2023-03-27
# Collected 8 headlines for 2023-03-28
# Collected 13 headlines for 2023-03-29
# Collected 11 headlines for 2023-03-30
# Collected 19 headlines for 2023-03-31
# Collected 2 headlines for 2023-04-01
# Collected 8 headlines for 2023-04-02
# Collected 10 headlines for 2023-04-03
# Collected 16 headlines for 2023-04-04
# Collected 12 headlines for 2023-04-05
# Collected 9 headlines for 2023-04-06
# Collected 18 headlines for 2023-04-07
# Collected 5 headlines for 2023-04-08
# Collected 3 headlines for 2023-04-09
# Collected 9 headlines for 2023-04-10
# Collected 11 headlines for 2023-04-11
# Collected 16 headlines for 2023-04-12
# Collected 9 headlines for 2023-04-13
# Collected 11 headlines for 2023-04-14
# Collected 4 headlines for 2023-04-15
# Collected 6 headlines for 2023-04-16
# Collected 10 headlines for 2023-04-17
# Collected 13 headlines for 2023-04-18
# Collected 15 headlines for 2023-04-19
# Collected 11 headlines for 2023-04-20
# Collected 11 headlines for 2023-04-21
# Collected 7 headlines for 2023-04-22
# Collected 3 headlines for 2023-04-23
# Collected 19 headlines for 2023-04-24
# Collected 14 headlines for 2023-04-25
# Collected 14 headlines for 2023-04-26
# Collected 17 headlines for 2023-04-27
# Collected 23 headlines for 2023-04-28
# Collected 7 headlines for 2023-04-29
# Collected 5 headlines for 2023-04-30
# Collected 16 headlines for 2023-05-01
# Collected 20 headlines for 2023-05-02
# Collected 21 headlines for 2023-05-03
# Collected 16 headlines for 2023-05-04
# Collected 15 headlines for 2023-05-05
# Collected 4 headlines for 2023-05-06
# Collected 6 headlines for 2023-05-07
# Collected 11 headlines for 2023-05-08
# Collected 18 headlines for 2023-05-09
# Collected 16 headlines for 2023-05-10
# Collected 17 headlines for 2023-05-11
# Collected 14 headlines for 2023-05-12
# Collected 5 headlines for 2023-05-13
# Collected 6 headlines for 2023-05-14
# Collected 10 headlines for 2023-05-15
# Collected 12 headlines for 2023-05-16
# Collected 7 headlines for 2023-05-17
# Collected 19 headlines for 2023-05-18
# Collected 14 headlines for 2023-05-19
# Collected 9 headlines for 2023-05-20
# Collected 5 headlines for 2023-05-21
# Collected 12 headlines for 2023-05-22
# Collected 8 headlines for 2023-05-23
# Collected 12 headlines for 2023-05-24
# Collected 16 headlines for 2023-05-25
# Collected 11 headlines for 2023-05-26
# Collected 6 headlines for 2023-05-27
# Collected 1 headlines for 2023-05-28
# Collected 2 headlines for 2023-05-29
# Collected 10 headlines for 2023-05-30
# Collected 11 headlines for 2023-05-31
# Collected 8 headlines for 2023-06-01
# Collected 19 headlines for 2023-06-02
# Collected 3 headlines for 2023-06-03
# Collected 11 headlines for 2023-06-04
# Collected 7 headlines for 2023-06-05
# Collected 12 headlines for 2023-06-06
# Collected 16 headlines for 2023-06-07
# Collected 15 headlines for 2023-06-08
# Collected 13 headlines for 2023-06-09
# Collected 5 headlines for 2023-06-10
# Collected 2 headlines for 2023-06-11
# Collected 13 headlines for 2023-06-12
# Collected 10 headlines for 2023-06-13
# Collected 18 headlines for 2023-06-14
# Collected 15 headlines for 2023-06-15
# Collected 20 headlines for 2023-06-16
# Collected 4 headlines for 2023-06-17
# Collected 5 headlines for 2023-06-18
# Collected 5 headlines for 2023-06-19
# Collected 8 headlines for 2023-06-20
# Collected 13 headlines for 2023-06-21
# Collected 14 headlines for 2023-06-22
# Collected 15 headlines for 2023-06-23
# Collected 7 headlines for 2023-06-24
# Collected 2 headlines for 2023-06-25
# Collected 10 headlines for 2023-06-26
# Collected 12 headlines for 2023-06-27
# Collected 12 headlines for 2023-06-28
# Collected 14 headlines for 2023-06-29
# Collected 13 headlines for 2023-06-30
# Collected 7 headlines for 2023-07-01
# Collected 6 headlines for 2023-07-02
# Collected 7 headlines for 2023-07-03
# Collected 7 headlines for 2023-07-04
# Collected 14 headlines for 2023-07-05
# Collected 10 headlines for 2023-07-06
# Collected 15 headlines for 2023-07-07
# Collected 10 headlines for 2023-07-08
# Collected 4 headlines for 2023-07-09
# Collected 9 headlines for 2023-07-10
# Collected 11 headlines for 2023-07-11
# Collected 14 headlines for 2023-07-12
# Collected 17 headlines for 2023-07-13
# Collected 21 headlines for 2023-07-14
# Collected 5 headlines for 2023-07-15
# Collected 6 headlines for 2023-07-16
# Collected 8 headlines for 2023-07-17
# Collected 13 headlines for 2023-07-18
# Collected 20 headlines for 2023-07-19
# Collected 18 headlines for 2023-07-20
# Collected 15 headlines for 2023-07-21
# Collected 9 headlines for 2023-07-22
# Collected 2 headlines for 2023-07-23
# Collected 7 headlines for 2023-07-24
# Collected 13 headlines for 2023-07-25
# Collected 18 headlines for 2023-07-26
# Collected 17 headlines for 2023-07-27
# Collected 17 headlines for 2023-07-28
# Collected 6 headlines for 2023-07-29
# Collected 5 headlines for 2023-07-30
# Collected 8 headlines for 2023-07-31
# Collected 10 headlines for 2023-08-01
# Collected 12 headlines for 2023-08-02
# Collected 13 headlines for 2023-08-03
# Collected 14 headlines for 2023-08-04
# Collected 5 headlines for 2023-08-05
# Collected 6 headlines for 2023-08-06
# Collected 13 headlines for 2023-08-07
# Collected 10 headlines for 2023-08-08
# Collected 11 headlines for 2023-08-09
# Collected 14 headlines for 2023-08-10
# Collected 16 headlines for 2023-08-11
# Collected 4 headlines for 2023-08-12
# Collected 6 headlines for 2023-08-13
# Collected 6 headlines for 2023-08-14
# Collected 12 headlines for 2023-08-15
# Collected 16 headlines for 2023-08-16
# Collected 12 headlines for 2023-08-17
# Collected 9 headlines for 2023-08-18
# Collected 7 headlines for 2023-08-19
# Collected 3 headlines for 2023-08-20
# Collected 12 headlines for 2023-08-21
# Collected 7 headlines for 2023-08-22
# Collected 10 headlines for 2023-08-23
# Collected 11 headlines for 2023-08-24
# Collected 13 headlines for 2023-08-25
# Collected 4 headlines for 2023-08-26
# Collected 3 headlines for 2023-08-27
# Collected 10 headlines for 2023-08-28
# Collected 16 headlines for 2023-08-29
# Collected 14 headlines for 2023-08-30
# Collected 5 headlines for 2023-08-31
# Collected 20 headlines for 2023-09-01
# Collected 5 headlines for 2023-09-02
# Collected 3 headlines for 2023-09-03
# Collected 4 headlines for 2023-09-04
# Collected 14 headlines for 2023-09-05
# Collected 8 headlines for 2023-09-06
# Collected 12 headlines for 2023-09-07
# Collected 12 headlines for 2023-09-08
# Collected 8 headlines for 2023-09-09
# Collected 3 headlines for 2023-09-10
# Collected 14 headlines for 2023-09-11
# Collected 19 headlines for 2023-09-12
# Collected 20 headlines for 2023-09-13
# Collected 12 headlines for 2023-09-14
# Collected 19 headlines for 2023-09-15
# Collected 7 headlines for 2023-09-16
# Collected 2 headlines for 2023-09-17
# Collected 8 headlines for 2023-09-18
# Collected 15 headlines for 2023-09-19
# Collected 14 headlines for 2023-09-20
# Collected 13 headlines for 2023-09-21
# Collected 18 headlines for 2023-09-22
# Collected 6 headlines for 2023-09-23
# Collected 3 headlines for 2023-09-24
# Collected 13 headlines for 2023-09-25
# Collected 13 headlines for 2023-09-26
# Collected 18 headlines for 2023-09-27
# Collected 21 headlines for 2023-09-28
# Collected 21 headlines for 2023-09-29
# Collected 6 headlines for 2023-09-30
# Collected 5 headlines for 2023-10-01
# Collected 9 headlines for 2023-10-02
# Collected 14 headlines for 2023-10-03
# Collected 11 headlines for 2023-10-04
# Collected 14 headlines for 2023-10-05
# Collected 18 headlines for 2023-10-06
# Collected 5 headlines for 2023-10-07
# Collected 3 headlines for 2023-10-08
# Collected 13 headlines for 2023-10-09
# Collected 13 headlines for 2023-10-10
# Collected 16 headlines for 2023-10-11
# Collected 17 headlines for 2023-10-12
# Collected 16 headlines for 2023-10-13
# Collected 6 headlines for 2023-10-14
# Collected 6 headlines for 2023-10-15
# Collected 10 headlines for 2023-10-16
# Collected 12 headlines for 2023-10-17
# Collected 16 headlines for 2023-10-18
# Collected 17 headlines for 2023-10-19
# Collected 14 headlines for 2023-10-20
# Collected 6 headlines for 2023-10-21
# Collected 4 headlines for 2023-10-22
# Collected 12 headlines for 2023-10-23
# Collected 15 headlines for 2023-10-24
# Collected 10 headlines for 2023-10-25
# Collected 16 headlines for 2023-10-26
# Collected 15 headlines for 2023-10-27
# Collected 6 headlines for 2023-10-28
# Collected 6 headlines for 2023-10-29
# Collected 13 headlines for 2023-10-30
# Collected 11 headlines for 2023-10-31
# Collected 20 headlines for 2023-11-01
# Collected 21 headlines for 2023-11-02
# Collected 19 headlines for 2023-11-03
# Collected 6 headlines for 2023-11-04
# Collected 5 headlines for 2023-11-05
# Collected 9 headlines for 2023-11-06
# Collected 12 headlines for 2023-11-07
# Collected 18 headlines for 2023-11-08
# Collected 19 headlines for 2023-11-09
# Collected 14 headlines for 2023-11-10
# Collected 6 headlines for 2023-11-11
# Collected 6 headlines for 2023-11-12
# Collected 7 headlines for 2023-11-13
# Collected 11 headlines for 2023-11-14
# Collected 14 headlines for 2023-11-15
# Collected 12 headlines for 2023-11-16
# Collected 15 headlines for 2023-11-17
# Collected 8 headlines for 2023-11-18
# Collected 5 headlines for 2023-11-19
# Collected 11 headlines for 2023-11-20
# Collected 16 headlines for 2023-11-21
# Collected 13 headlines for 2023-11-22
# Collected 5 headlines for 2023-11-23
# Collected 8 headlines for 2023-11-24
# Collected 2 headlines for 2023-11-25
# Collected 3 headlines for 2023-11-26
# Collected 3 headlines for 2023-11-27
# Collected 13 headlines for 2023-11-28
# Collected 24 headlines for 2023-11-29
# Collected 11 headlines for 2023-11-30
# Collected 14 headlines for 2023-12-01
# Collected 6 headlines for 2023-12-02
# Collected 8 headlines for 2023-12-03
# Collected 6 headlines for 2023-12-04
# Collected 14 headlines for 2023-12-05
# Collected 24 headlines for 2023-12-06
# Collected 10 headlines for 2023-12-07
# Collected 18 headlines for 2023-12-08
# Collected 15 headlines for 2023-12-09
# Collected 8 headlines for 2023-12-10
# Collected 11 headlines for 2023-12-11
# Collected 16 headlines for 2023-12-12
# Collected 17 headlines for 2023-12-13
# Collected 20 headlines for 2023-12-14
# Collected 10 headlines for 2023-12-15
# Collected 5 headlines for 2023-12-16
# Collected 2 headlines for 2023-12-17
# Collected 11 headlines for 2023-12-18
# Collected 11 headlines for 2023-12-19
# Collected 12 headlines for 2023-12-20
# Collected 14 headlines for 2023-12-21
# Collected 13 headlines for 2023-12-22
# Collected 5 headlines for 2023-12-23
# Collected 2 headlines for 2023-12-24
# Collected 2 headlines for 2023-12-25
# Collected 3 headlines for 2023-12-26
# Collected 8 headlines for 2023-12-27
# Collected 6 headlines for 2023-12-28
# Collected 8 headlines for 2023-12-29
# Collected 6 headlines for 2023-12-30
# Collected 1 headlines for 2023-12-31
# Collected 5 headlines for 2024-01-01
# Collected 6 headlines for 2024-01-02
# Collected 7 headlines for 2024-01-03
# Collected 5 headlines for 2024-01-04
# Collected 13 headlines for 2024-01-05
# Collected 9 headlines for 2024-01-06
# Collected 5 headlines for 2024-01-07
# Collected 10 headlines for 2024-01-08
# Collected 14 headlines for 2024-01-09
# Collected 12 headlines for 2024-01-10
# Collected 18 headlines for 2024-01-11
# Collected 15 headlines for 2024-01-12
# Collected 5 headlines for 2024-01-13
# Collected 4 headlines for 2024-01-14
# Collected 4 headlines for 2024-01-15
# Collected 12 headlines for 2024-01-16
# Collected 18 headlines for 2024-01-17
# Collected 9 headlines for 2024-01-18
# Collected 18 headlines for 2024-01-19
# Collected 7 headlines for 2024-01-20
# Collected 3 headlines for 2024-01-21
# Collected 15 headlines for 2024-01-22
# Collected 11 headlines for 2024-01-23
# Collected 14 headlines for 2024-01-24
# Collected 21 headlines for 2024-01-25
# Collected 15 headlines for 2024-01-26
# Collected 8 headlines for 2024-01-27
# Collected 4 headlines for 2024-01-28
# Collected 11 headlines for 2024-01-29
# Collected 20 headlines for 2024-01-30
# Collected 13 headlines for 2024-01-31
# Collected 17 headlines for 2024-02-01
# Collected 19 headlines for 2024-02-02
# Collected 7 headlines for 2024-02-03
# Collected 4 headlines for 2024-02-04
# Collected 17 headlines for 2024-02-05
# Collected 14 headlines for 2024-02-06
# Collected 12 headlines for 2024-02-07
# Collected 15 headlines for 2024-02-08
# Collected 11 headlines for 2024-02-09
# Collected 4 headlines for 2024-02-10
# Collected 2 headlines for 2024-02-11
# Collected 7 headlines for 2024-02-12
# Collected 14 headlines for 2024-02-13
# Collected 16 headlines for 2024-02-14
# Collected 11 headlines for 2024-02-15
# Collected 15 headlines for 2024-02-16
# Collected 5 headlines for 2024-02-17
# Collected 5 headlines for 2024-02-18
# Collected 8 headlines for 2024-02-19
# Collected 10 headlines for 2024-02-20
# Collected 17 headlines for 2024-02-21
# Collected 14 headlines for 2024-02-22
# Collected 14 headlines for 2024-02-23
# Collected 3 headlines for 2024-02-24
# Collected 5 headlines for 2024-02-25
# Collected 7 headlines for 2024-02-26
# Collected 12 headlines for 2024-02-27
# Collected 16 headlines for 2024-02-28
# Collected 7 headlines for 2024-02-29
# Collected 16 headlines for 2024-03-01
# Collected 8 headlines for 2024-03-02
# Collected 4 headlines for 2024-03-03
# Collected 15 headlines for 2024-03-04
# Collected 16 headlines for 2024-03-05
# Collected 11 headlines for 2024-03-06
# Collected 13 headlines for 2024-03-07
# Collected 15 headlines for 2024-03-08
# Collected 11 headlines for 2024-03-09
# Collected 3 headlines for 2024-03-10
# Collected 5 headlines for 2024-03-11
# Collected 13 headlines for 2024-03-12
# Collected 16 headlines for 2024-03-13
# Collected 13 headlines for 2024-03-14
# Collected 14 headlines for 2024-03-15
# Collected 10 headlines for 2024-03-16
# Collected 1 headlines for 2024-03-17
# Collected 10 headlines for 2024-03-18
# Collected 17 headlines for 2024-03-19
# Collected 17 headlines for 2024-03-20
# Collected 13 headlines for 2024-03-21
# Collected 19 headlines for 2024-03-22
# Collected 4 headlines for 2024-03-23
# Collected 6 headlines for 2024-03-24
# Collected 13 headlines for 2024-03-25
# Collected 12 headlines for 2024-03-26
# Collected 17 headlines for 2024-03-27
# Collected 14 headlines for 2024-03-28
# Collected 10 headlines for 2024-03-29
# Collected 5 headlines for 2024-03-30
# Collected 2 headlines for 2024-03-31
# Collected 12 headlines for 2024-04-01
# Collected 7 headlines for 2024-04-02
# Collected 10 headlines for 2024-04-03
# Collected 8 headlines for 2024-04-04
# Collected 15 headlines for 2024-04-05
# Collected 8 headlines for 2024-04-06
# Collected 6 headlines for 2024-04-07
# Collected 11 headlines for 2024-04-08
# Collected 15 headlines for 2024-04-09
# Collected 10 headlines for 2024-04-10
# Headlines successfully collected and saved to finance_headlines.csv
